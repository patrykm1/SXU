# %%
import numpy as np
import pandas as pd
cars = pd.read_csv('samochody1tys.csv')

# %%
#wyświetlenie zawartości pliku
cars
# Out:
#       id       marka        model  rok_produkcji rodzaj_silnika  \
# 0      0      Nissan  X-Trail III         2014.0         Diesel
# 1      1         BMW       X1 E84         2012.0         Diesel
# 2      2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3      3     Hyundai        i10 I         2008.0        Benzyna
# 4      4  Volkswagen           CC         2010.0         Diesel
# ..   ...         ...          ...            ...            ...
# 995  995  Alfa Romeo          159         2009.0         Diesel
# 996  996       Škoda     Fabia II         2012.0        Benzyna
# 997  997     Renault        Modus         2004.0        Benzyna
# 998  998        Audi        A3 8L         2000.0        Benzyna
# 999  999       Volvo      XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# 0               1600.0  160000.0   75900.0    Dolnośląskie
# 1               2000.0  149000.0   70900.0  Świętokrzyskie
# ...

# %%
#wyświetlenie pięciu pierwszych wierszy
cars.head()
# Out:
#    id       marka        model  rok_produkcji rodzaj_silnika  \
# 0   0      Nissan  X-Trail III         2014.0         Diesel
# 1   1         BMW       X1 E84         2012.0         Diesel
# 2   2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3   3     Hyundai        i10 I         2008.0        Benzyna
# 4   4  Volkswagen           CC         2010.0         Diesel
#
#    pojemnosc_silnika  przebieg     cena     wojewodztwo
# 0             1600.0  160000.0  75900.0    Dolnośląskie
# 1             2000.0  149000.0  70900.0  Świętokrzyskie
# 2             1600.0   99000.0   9800.0        Opolskie
# 3             1100.0   93000.0  11900.0         Łódzkie
# 4             1968.0  127428.0  49900.0   Wielkopolskie

# %%
#wyświetlenie konkretnego rekordu
cars.iloc[156]
# Out:
# id                           156
# marka                    Renault
# model                    Clio IV
# rok_produkcji               2017
# rodzaj_silnika           Benzyna
# pojemnosc_silnika            898
# przebieg                       9
# cena                       54960
# wojewodztwo          Mazowieckie
# Name: 156, dtype: object

# %%
#Wyświetlanie ostatnich 8 rekordów 
cars.tail(8)
# Out:
#       id       marka     model  rok_produkcji rodzaj_silnika  \
# 992  992     Renault   Clio IV         2017.0        Benzyna
# 993  993        Fiat   Tipo II         2017.0        Benzyna
# 994  994        Fiat  Bravo II         2007.0         Diesel
# 995  995  Alfa Romeo       159         2009.0         Diesel
# 996  996       Škoda  Fabia II         2012.0        Benzyna
# 997  997     Renault     Modus         2004.0        Benzyna
# 998  998        Audi     A3 8L         2000.0        Benzyna
# 999  999       Volvo   XC 60 I         2016.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# 992              898.0       1.0   58000.0         Śląskie
# 993             1400.0       2.0   47350.0     Mazowieckie
# 994             1910.0  217200.0   18900.0  Świętokrzyskie
# 995             2387.0  182000.0   33900.0     Małopolskie
# 996             1200.0   42700.0   25400.0       Lubelskie
# 997             1200.0  168111.0   10900.0         Łódzkie
# ...

# %%
#wyswietlenie indeksu
cars.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#wyświetlenie rekordów z danego przedziału
cars[145:177]
# Out:
#       id          marka            model  rok_produkcji rodzaj_silnika  \
# 145  145            BMW      Seria 3 F30         2015.0         Diesel
# 146  146          Volvo            V40 I         2000.0         Diesel
# 147  147           Seat           Leon I         2001.0        Benzyna
# 148  148           Ford       Mondeo Mk3         2004.0        Benzyna
# 149  149        Hyundai        Tucson II         2017.0         Diesel
# 150  150        Renault       Megane III         2009.0        Benzyna
# 151  151           Audi               R8         2008.0        Benzyna
# 152  152     Volkswagen          Golf VI         2009.0        Benzyna
# 153  153           Audi            A5 F5         2017.0         Diesel
# 154  154         Toyota       Avensis II         2008.0        Benzyna
# 155  155        Peugeot              208         2016.0        Benzyna
# 156  156        Renault          Clio IV         2017.0        Benzyna
# ...

# %%
#wyświetlenie rekordów z danego przedziału z wybranymi kolumnami
cars.loc[145:177,['id','marka', 'model','rok_produkcji', 'cena']]
# Out:
#       id          marka            model  rok_produkcji      cena
# 145  145            BMW      Seria 3 F30         2015.0   89800.0
# 146  146          Volvo            V40 I         2000.0    6900.0
# 147  147           Seat           Leon I         2001.0   10999.0
# 148  148           Ford       Mondeo Mk3         2004.0   13900.0
# 149  149        Hyundai        Tucson II         2017.0  144900.0
# 150  150        Renault       Megane III         2009.0   26900.0
# 151  151           Audi               R8         2008.0  239900.0
# 152  152     Volkswagen          Golf VI         2009.0   26900.0
# 153  153           Audi            A5 F5         2017.0  240900.0
# 154  154         Toyota       Avensis II         2008.0   28500.0
# 155  155        Peugeot              208         2016.0   39900.0
# 156  156        Renault          Clio IV         2017.0   54960.0
# 157  157         Toyota    Corolla Seria         2003.0   11900.0
# ...

# %%
#wyświetla konkretną kolumnę
cars['model']
# Out:
# 0      X-Trail III
# 1           X1 E84
# 2         Zafira A
# 3            i10 I
# 4               CC
#           ...
# 995            159
# 996       Fabia II
# 997          Modus
# 998          A3 8L
# 999        XC 60 I
# Name: model, Length: 1000, dtype: object

# %%
#wyświetlenie konkretnych rekordów pokazując wybrane kolumny
cars.iloc[[0,4,168,222,368,433,611,750,999],[1,2,3,7]]
# Out:
#           marka        model  rok_produkcji      cena
# 0        Nissan  X-Trail III         2014.0   75900.0
# 4    Volkswagen           CC         2010.0   49900.0
# 168     Peugeot       5008 I         2014.0   39900.0
# 222        Audi        A6 C7         2016.0  219000.0
# 368     Hyundai        I30 I         2010.0   19999.0
# 433       Dacia   Sandero II         2016.0   49000.0
# 611   Chevrolet       Camaro         1979.0   36000.0
# 750       Škoda        RAPID         2016.0   55900.0
# 999       Volvo      XC 60 I         2016.0  136900.0

# %%
#wyświelenie wszystkich kolumn wskazanego zakresu
cars.iloc[100:122, :]
# Out:
#       id          marka        model  rok_produkcji rodzaj_silnika  \
# 100  100     Volkswagen     Touran I         2003.0        Benzyna
# 101  101        Hyundai        i10 I         2009.0        Benzyna
# 102  102     Mitsubishi          ASX         2014.0         Diesel
# 103  103           Audi        A4 B7         2007.0         Diesel
# 104  104           Opel       Antara         2009.0         Diesel
# 105  105         Suzuki         Alto         2002.0        Benzyna
# 106  106        Citroën   Berlingo I         2005.0         Diesel
# 107  107     Volkswagen     Polo III         2001.0        Benzyna
# 108  108           Opel     Zafira B         2009.0         Diesel
# 109  109        Peugeot         2008         2017.0        Benzyna
# 110  110     Volkswagen     Touran I         2005.0         Diesel
# 111  111        Renault    Megane II         2007.0        Benzyna
# 112  112          Mazda         3 II         2009.0         Diesel
# ...

# %%
#wyświelenie wskazanych kolumn wszystkich wierszy
cars.iloc[: , 1:4]
# Out:
#           marka        model  rok_produkcji
# 0        Nissan  X-Trail III         2014.0
# 1           BMW       X1 E84         2012.0
# 2          Opel     Zafira A         2004.0
# 3       Hyundai        i10 I         2008.0
# 4    Volkswagen           CC         2010.0
# ..          ...          ...            ...
# 995  Alfa Romeo          159         2009.0
# 996       Škoda     Fabia II         2012.0
# 997     Renault        Modus         2004.0
# 998        Audi        A3 8L         2000.0
# 999       Volvo      XC 60 I         2016.0
#
# [1000 rows x 3 columns]

# %%
#zwraca ilość zliczonych elementów podanej kolumny
cars['marka'].value_counts()
# Out:
# Opel             105
# Volkswagen        92
# Audi              70
# BMW               66
# Mercedes-Benz     59
# Renault           59
# Ford              59
# Toyota            49
# Peugeot           41
# Citroën           40
# Škoda             36
# Nissan            33
# Fiat              33
# Hyundai           31
# Honda             25
# Kia               25
# Volvo             24
# Mazda             21
# Seat              20
# Mitsubishi        18
# Suzuki            16
# Chevrolet         11
# Mini              11
# Lexus              7
# Jeep               6
# Dodge              5
# Land Rover         5
# Dacia              5
# Alfa Romeo         5
# SsangYong          3
# Saab               3
# Daewoo             2
# Porsche            2
# Smart              2
# Infiniti           2
# Jaguar             2
# Chrysler           1
# Pontiac            1
# Lancia             1
# Maserati           1
# Subaru             1
# Ligier             1
# Daihatsu           1
# ...

# %%
#zwraca pojazdy z ceną mniejszą niż 5000
cars[cars.cena < 5000]
# Out:
#       id          marka             model  rok_produkcji rodzaj_silnika  \
# 34    34        Citroën          Xsara II         2002.0        Benzyna
# 46    46          Honda        Civic VIII         1997.0        Benzyna
# 68    68        Pontiac       Trans Sport         1994.0    Benzyna+LPG
# 105  105         Suzuki              Alto         2002.0        Benzyna
# 192  192        Renault            Thalia         2004.0         Diesel
# 194  194        Citroën     Xsara Picasso         2000.0        Benzyna
# 195  195          Volvo             V40 I         2001.0         Diesel
# 201  201           Ford         Focus Mk1         2000.0        Benzyna
# 210  210           Fiat           Doblo I         2002.0         Diesel
# 238  238  Mercedes-Benz  W124 (1984-1993)         1991.0         Diesel
# 249  249         Daewoo              Tico         2000.0        Benzyna
# 251  251     Volkswagen           Golf IV         2001.0        Benzyna
# ...

# %%
#transpozycja  zawartości pliku
cars.T
# Out:
#                             0               1            2        3    \
# id                            0               1            2        3
# marka                    Nissan             BMW         Opel  Hyundai
# model               X-Trail III          X1 E84     Zafira A    i10 I
# rok_produkcji              2014            2012         2004     2008
# rodzaj_silnika           Diesel          Diesel  Benzyna+CNG  Benzyna
# pojemnosc_silnika          1600            2000         1600     1100
# przebieg                 160000          149000        99000    93000
# cena                      75900           70900         9800    11900
# wojewodztwo        Dolnośląskie  Świętokrzyskie     Opolskie  Łódzkie
#
#                              4            5             6          7    \
# id                             4            5             6          7
# marka                 Volkswagen         Fiat        Nissan       Seat
# ...

# %%
#wyświetlenie typów każdej z kolumn
cars.dtypes
# Out:
# id                     int64
# marka                 object
# model                 object
# rok_produkcji        float64
# rodzaj_silnika        object
# pojemnosc_silnika    float64
# przebieg             float64
# cena                 float64
# wojewodztwo           object
# dtype: object

# %%
#sortowanie według ceny
cars.sort_values('cena')
# Out:
#       id          marka                 model  rok_produkcji rodzaj_silnika  \
# 249  249         Daewoo                  Tico         2000.0        Benzyna
# 626  626     Mitsubishi              Colt CJ0         1997.0        Benzyna
# 497  497           Fiat                 Brava         1998.0        Benzyna
# 321  321     Volkswagen              Polo III         1998.0        Benzyna
# 487  487     Mitsubishi              Colt CJ0         2002.0        Benzyna
# ..   ...            ...                   ...            ...            ...
# 410  410            BMW        Seria 7 G11/12         2017.0        Hybryda
# 517  517           Audi                   RS7         2016.0        Benzyna
# 855  855     Land Rover  Range Rover Sport II         2016.0        Benzyna
# 586  586  Mercedes-Benz          Klasa G W463         2013.0        Benzyna
# 405  405  Mercedes-Benz               SL R231         2016.0        Benzyna
#
# ...

# %%
#sortowanie według ceny malejąco
cars.sort_values('cena',ascending=False)
# Out:
#       id          marka                 model  rok_produkcji rodzaj_silnika  \
# 405  405  Mercedes-Benz               SL R231         2016.0        Benzyna
# 586  586  Mercedes-Benz          Klasa G W463         2013.0        Benzyna
# 855  855     Land Rover  Range Rover Sport II         2016.0        Benzyna
# 517  517           Audi                   RS7         2016.0        Benzyna
# 410  410            BMW        Seria 7 G11/12         2017.0        Hybryda
# ..   ...            ...                   ...            ...            ...
# 487  487     Mitsubishi              Colt CJ0         2002.0        Benzyna
# 321  321     Volkswagen              Polo III         1998.0        Benzyna
# 497  497           Fiat                 Brava         1998.0        Benzyna
# 626  626     Mitsubishi              Colt CJ0         1997.0        Benzyna
# 249  249         Daewoo                  Tico         2000.0        Benzyna
#
# ...

# %%
#wyświetla posortowane dane według podanych kolumn
cars.sort_values(by=["marka","model"])
# Out:
#       id       marka       model  rok_produkcji rodzaj_silnika  \
# 300  300  Alfa Romeo         147         2002.0        Benzyna
# 213  213  Alfa Romeo         156         2004.0         Diesel
# 370  370  Alfa Romeo         159         2007.0         Diesel
# 995  995  Alfa Romeo         159         2009.0         Diesel
# 705  705  Alfa Romeo      Spider         1995.0    Benzyna+LPG
# ..   ...         ...         ...            ...            ...
# 334  334       Škoda       RAPID         2017.0         Diesel
# 750  750       Škoda       RAPID         2016.0        Benzyna
# 159  159       Škoda  Superb III         2016.0         Diesel
# 295  295       Škoda  Superb III         2017.0         Diesel
# 957  957       Škoda  Superb III         2016.0        Benzyna
#
#      pojemnosc_silnika  przebieg      cena    wojewodztwo
# 300             2000.0  200000.0    4100.0      Lubelskie
# 213             1900.0  284000.0    6900.0      Lubelskie
# ...

# %%
#wyświetla tablice której zawartość została sprowadzona do wspolnego typu danych (Object)
cars.to_numpy()
# Out:
# array([[0, 'Nissan', 'X-Trail III', ..., 160000.0, 75900.0,
#         'Dolnośląskie'],
#        [1, 'BMW', 'X1 E84', ..., 149000.0, 70900.0, 'Świętokrzyskie'],
#        [2, 'Opel', 'Zafira A', ..., 99000.0, 9800.0, 'Opolskie'],
#        ...,
#        [997, 'Renault', 'Modus', ..., 168111.0, 10900.0, 'Łódzkie'],
#        [998, 'Audi', 'A3 8L', ..., 226500.0, 5400.0, 'Małopolskie'],
#        [999, 'Volvo', 'XC 60 I', ..., 13617.0, 136900.0, 'Małopolskie']],
#       dtype=object)

# %%
#wyświetla pojazdy wyprodukowane przed 1990
cars[cars.rok_produkcji < 1990]
# Out:
#       id          marka             model  rok_produkcji rodzaj_silnika  \
# 130  130  Mercedes-Benz      Klasa S W126         1984.0        Benzyna
# 484  484           Opel           Senator         1986.0        Benzyna
# 611  611      Chevrolet            Camaro         1979.0        Benzyna
# 650  650  Mercedes-Benz  W124 (1984-1993)         1988.0        Benzyna
# 704  704  Mercedes-Benz      Klasa S W126         1984.0        Benzyna
# 990  990  Mercedes-Benz      Klasa S W126         1986.0    Benzyna+LPG
#
#      pojemnosc_silnika  przebieg     cena     wojewodztwo
# 130             2800.0  147400.0  37500.0     Mazowieckie
# 484             3000.0   89000.0  14999.0    Podkarpackie
# 611             4903.0   99999.0  36000.0    Dolnośląskie
# 650             2300.0  270000.0  11900.0     Mazowieckie
# 704             5000.0  284205.0  37500.0       Lubelskie
# 990             2600.0  336000.0  21500.0  Świętokrzyskie

# %%
#wyświetla średnią każdej z kolumn
cars.mean()
# Out:
# id                      499.500
# rok_produkcji          2009.009
# pojemnosc_silnika      2040.065
# przebieg             132556.677
# cena                  51942.181
# dtype: float64

# %%
#sumowanie kolejnych wartości każdego z rekordów
cars[720:730].apply(np.cumsum)
# Out:
#        id                                              marka  \
# 720   720                                               Opel
# 721  1441                                         OpelNissan
# 722  2163                                     OpelNissanFord
# 723  2886                                OpelNissanFordHonda
# 724  3610                            OpelNissanFordHondaOpel
# 725  4335                       OpelNissanFordHondaOpelMazda
# 726  5061               OpelNissanFordHondaOpelMazdaMaserati
# 727  5788            OpelNissanFordHondaOpelMazdaMaseratiBMW
# 728  6516        OpelNissanFordHondaOpelMazdaMaseratiBMWOpel
# 729  7245  OpelNissanFordHondaOpelMazdaMaseratiBMWOpelRen...
#
#                                                  model  rok_produkcji  \
# 720                                           Vectra C         2007.0
# 721                                 Vectra CAlmera N16         4012.0
# 722                       Vectra CAlmera N16Mondeo Mk4         6027.0
# ...

# %%
#zwraca wartości true w tam gdzie zawartość jest NaN
pd.isna(cars)
# Out:
#         id  marka  model  rok_produkcji  rodzaj_silnika  pojemnosc_silnika  \
# 0    False  False  False          False           False              False
# 1    False  False  False          False           False              False
# 2    False  False  False          False           False              False
# 3    False  False  False          False           False              False
# 4    False  False  False          False           False              False
# ..     ...    ...    ...            ...             ...                ...
# 995  False  False  False          False           False              False
# 996  False  False  False          False           False              False
# 997  False  False  False          False           False              False
# 998  False  False  False          False           False              False
# 999  False  False  False          False           False              False
#
#      przebieg   cena  wojewodztwo
# ...

# %%
#grupowanie po konkretnych wartościach
cars.groupby(["marka", "rok_produkcji"]).sum()
# Out:
#                             id  pojemnosc_silnika  przebieg      cena
# marka      rok_produkcji
# Alfa Romeo 1995.0          705             2000.0  175000.0   10000.0
#            2002.0          300             2000.0  200000.0    4100.0
#            2004.0          213             1900.0  284000.0    6900.0
#            2007.0          370             1900.0  190000.0   19000.0
#            2009.0          995             2387.0  182000.0   33900.0
# ...                        ...                ...       ...       ...
# Škoda      2013.0          313             1600.0  146000.0   21900.0
#            2014.0         1323             3196.0  166926.0   79800.0
#            2015.0          285              999.0   63578.0   35400.0
#            2016.0         2286             7981.0   42263.0  505000.0
#            2017.0         3206            10812.0    4226.0  671980.0
#
# [396 rows x 4 columns]
